# %% [markdown]
# ### full batch: lr = 0.02 (epoch = 100)
# ![image-2.png](attachment:image-2.png)
# ##### last error = 32.93333333333334
# ***

# %% [markdown]
# ### full batch: lr = 0.01 (epoch = 100)
# ![image-3.png](attachment:image-3.png)
# ##### last error = 33.01166666666666
# ***

# %% [markdown]
# ### full batch: lr = 0.005 (epoch = 100)
# ![image.png](attachment:image.png)
# ##### last error = 33.468333333333334
# ***

# %% [markdown]
# ### full batch: lr = 0.003 (epoch = 100)
# ![image-2.png](attachment:image-2.png)
# ##### last error = 32.66833333333333
# ***

# %% [markdown]
# ### full batch: lr = 0.001 (epoch = 100)
# ![image.png](attachment:image.png)
# ##### last error = 33.656666666666666
# ***

# %% [markdown]
# ### mini batch: lr = 0.02 (batch_size = 1000)
# ![image.png](attachment:image.png)
# ##### last error = 32.70166666666666
# ***

# %% [markdown]
# ### mini batch: lr = 0.01 (batch_size = 1000)
# ![image-2.png](attachment:image-2.png)
# ##### last error = 32.64333333333334
# ***

# %% [markdown]
# ### mini batch: lr = 0.005 (batch_size = 1000)
# ![image.png](attachment:image.png)
# ##### last error = 32.70166666666666
# ***

# %% [markdown]
# ### mini batch: lr = 0.003 (batch_size = 1000)
# ![image-2.png](attachment:image-2.png)
# ##### last error = 32.60166666666666
# ***

# %% [markdown]
# ### mini batch: lr = 0.001 (batch_size = 1000)
# ![image.png](attachment:image.png)
# ##### last error = 33.27166666666667
# ***

# %% [markdown]
# ### mini batch: lr = 0.001 (batch_size = 1000, epoch = 20)
# ![image.png](attachment:image.png)
# ##### last error = 32.425000000000004
