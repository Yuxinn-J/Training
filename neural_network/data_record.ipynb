# %% [markdown]
# ### Epoch = 5
# ![image.png](attachment:image.png)
# ##### test accuracy: 87.21 %
# ***

# %% [markdown]
# ### Epoch = 3
# ![image.png](attachment:image.png)
# ##### test accuracy: 87.13 %
# ***

# %% [markdown]
# ### Epoch = 1
# # Loss: 2.6650147396905837
# ##### test accuracy: 84.59 %
# ***
# ***
# ***

# %% [markdown]
# ### Learning Rate = 1.0
# ![image.png](attachment:image.png)
# ##### test accuracy: 85.67 %
# ***

# %% [markdown]
# ### Learning Rate = 0.1
# ![image.png](attachment:image.png)
# ##### test accuracy: 86.46000000000001 %
# ***

# %% [markdown]
# ### Learning Rate = 0.01
# ![image.png](attachment:image.png)
# ##### test accuracy: 87.18 %
# ***

# %% [markdown]
# ### Learning Rate = 0.001
# ![image.png](attachment:image.png)
# ##### test accuracy: 85.64%
# ***

# %% [markdown]
# ### y = wx + b
# ![image.png](attachment:image.png)
# ##### test accuracy: 87.22999999999999 %
# ***
